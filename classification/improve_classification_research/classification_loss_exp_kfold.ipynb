# %%
import sys
sys.path.append('../..')

from utils import (load_data, CLASSIFICATION, REGRESSION, save_conf_matrix, 
                  TRAIN, TEST, MakiKFoldBalance, foldername2class)
import numpy as np
import os
os.environ["CUDA_VISIBLE_DEVICES"] = str(0)
import matplotlib.pyplot as plt 
import sys
from glob import glob
from sklearn.utils import shuffle
import json
import copy


import tensorflow as tf
tf.config.optimizer.set_jit(False)

from tensorflow.python.platform import tf_logging as logging
from tensorflow.keras import Model
import tensorflow.keras.layers as L
from tensorflow.keras.utils import to_categorical
from classification_models.tfkeras import Classifiers
import tensorflow_addons as tfa

MODEL = 'resnet101'

USE_L1 = 'use_l1'
USE_L2 = 'use_l2'
USE_LABEL_SMOOTHING = 'use_label_smoothing'

L1_REG_15 = lambda: tf.keras.regularizers.l1(1e-5)
L2_REG_14 = lambda: tf.keras.regularizers.l2(1e-4)
L1_L2_REG_15_14 = lambda: tf.keras.regularizers.l1_l2(1e-5, 1e-4)
ALL_L1_L2 = [L2_REG_14]
ALL_L1 = [L1_REG_15]
ALL_L2 = [L1_L2_REG_15_14]
ALL_REG = ALL_L1_L2 + ALL_L1 + ALL_L2 + [None]

LABEL_SMOOTHING_VARS = [0.0]

class ExpConfig:
    reg: callable = None
    label_smoothing = None
    
    def to_dict(self) -> dict:
        return {
            'reg': self.reg().get_config() if self.reg is not None else self.reg,
            'label_smoothing': self.label_smoothing, 
        }
    
EPOCHS = 30
BATCH_SIZE = 32
ITERATIONS_PER_EPOCH = 30_000 // BATCH_SIZE
NUM_K = 10
NUM_CLASSES = 21
PATH_DATASET = '../../double_modes'
SAVE_EXP_PATH = '/raid/rustam/danil/beams_loss_test'

# %%
@tf.function
def normalize_data(Xdata, Ydata):
    Xdata = tf.cast(Xdata, tf.float32)
    Xdata -= 128.0
    Xdata /= 128.0
    return Xdata, Ydata

@tf.function
def aug_noise(Xdata, Ydata):
    Xdata = tf.cast(Xdata, tf.float32)
    Xdata -= tf.random.normal(tf.shape(Xdata))
    return Xdata, Ydata

@tf.function
def aug_rotate(Xdata, Ydata, min_angle=0, max_angle=180):
    Xdata = tfa.image.rotate(
        Xdata,
        tf.random.uniform((tf.shape(Xdata)[0],), min_angle, max_angle),
        interpolation='nearest',
        fill_mode='reflect'
    )
    return Xdata, Ydata

@tf.function
def aug_cutout(Xdata, Ydata):
    mask = tf.ones_like(Xdata)
    size_cutout = tf.random.uniform([], 16, 32, dtype=tf.int32) // 2 * 2
    mask_cutout = tfa.image.random_cutout(mask, (size_cutout, size_cutout))
    noise_data = tf.ones_like(Xdata) * tf.random.normal(tf.shape(Xdata))
    Xdata = (1.0 - mask_cutout) * noise_data + Xdata * mask_cutout
    return Xdata, Ydata

@tf.function
def aug_brightness(Xdata, Ydata, parameter_bright=0.2):
    Xdata = tf.image.random_brightness(Xdata, parameter_bright)
    return Xdata, Ydata

@tf.function
def aug_contrast(Xdata, Ydata, min_cont=0.5, max_cont=2.0):
    Xdata = tf.image.random_contrast(Xdata, min_cont, max_cont)
    return Xdata, Ydata

@tf.function
def aug_saturation(Xdata, Ydata, min_saturation=0.75, max_saturation=1.25):
    Xdata = tf.image.random_contrast(Xdata, min_saturation, max_saturation)
    return Xdata, Ydata

def data_gen(Xdata, Ydata):
    counter = 0
    while True:
        yield Xdata[counter], Ydata[counter]
        
        counter += 1
        if counter == len(Xdata):
            counter = 0


def create_dataset(Xdata, Ydata_onehot, batch_size):
    tf_dataset = tf.data.Dataset.from_generator(
        lambda: data_gen(Xdata, Ydata_onehot),
        output_signature=(
            tf.TensorSpec(shape=(128, 128, 3), dtype=tf.uint8),
            tf.TensorSpec(shape=(NUM_CLASSES,), dtype=tf.int32),
        )
    )
    tf_dataset = tf_dataset.cache()
    tf_dataset = tf_dataset.shuffle(batch_size * 6, reshuffle_each_iteration=True)
    tf_dataset = tf_dataset.batch(batch_size)
    tf_dataset = tf_dataset.map(aug_noise, num_parallel_calls=tf.data.AUTOTUNE)
    tf_dataset = tf_dataset.map(normalize_data, num_parallel_calls=tf.data.AUTOTUNE)
    tf_dataset = tf_dataset.map(aug_rotate, num_parallel_calls=tf.data.AUTOTUNE)
    tf_dataset = tf_dataset.map(aug_cutout, num_parallel_calls=tf.data.AUTOTUNE)
    tf_dataset = tf_dataset.map(aug_brightness, num_parallel_calls=tf.data.AUTOTUNE)
    tf_dataset = tf_dataset.map(aug_contrast, num_parallel_calls=tf.data.AUTOTUNE)
    tf_dataset = tf_dataset.map(aug_saturation, num_parallel_calls=tf.data.AUTOTUNE)
    tf_dataset = tf_dataset.prefetch(4)
    return tf_dataset

# %%
class ConfMatrixCallback(tf.keras.callbacks.Callback):
    
    def __init__(self, path_save: str, model: Model, Xtest: np.ndarray, Ytest: np.ndarray):
        self.path_save = os.path.join(path_save, 'conf_matrix')
        self.model = model
        self.Xtest = Xtest
        self.Ytest = Ytest
        
        os.makedirs(self.path_save, exist_ok=True)
    
    def on_epoch_end(self, epoch, logs=None):
        predictions = self.model.predict(self.Xtest)
        predictions = tf.nn.softmax(predictions, axis=-1)
        predictions = tf.argmax(predictions, axis=-1)
        predictions = predictions.numpy()
        path_save = os.path.join(self.path_save, str(epoch))
        save_conf_matrix(
            self.Ytest, predictions, 
            path_save,
            save_np=True
        )
        logging.info(f'Confusion matrix written to: {path_save}')

# %%
def single_folder_exp(exp_config: ExpConfig, path_to_exp: str, resnet_model_creation: Model, epochs=30, batch_size=32):
    # At start of each experiments - create new dataset (shuffle it)
    Xtrain, Ytrain, Xtest, Ytest, pred2params, config_data = load_data(
        path_exp_folder=path_to_exp,
        path_to_data=PATH_DATASET,
        use_saved=True,
        size_hw=(128, 128),
        test_percent=None,
        data_type=CLASSIFICATION,
        filename_config='config_data'
    )
    Ytrain = np.asarray(Ytrain).astype(np.int32)
    Ytest = np.asarray(Ytest).astype(np.int32)
    
    Ytrain_onehot = to_categorical(Ytrain)
    Ytest_onehot = to_categorical(Ytest)
    
    Xtest, _ = normalize_data(np.asarray(Xtest), None)
    
    train_dataset = create_dataset(Xtrain, Ytrain_onehot, BATCH_SIZE)
    
    # Create a MirroredStrategy.
    #strategy = tf.distribute.MirroredStrategy()
    #print("Number of devices: {}".format(strategy.num_replicas_in_sync))

    # Open a strategy scope.
    #with strategy.scope():
    model_backbone = resnet_model_creation(
        include_top=False, weights=None, 
        input_shape=(128, 128, 3)
    )

    x = L.GlobalAveragePooling2D()(model_backbone.output)
    x = L.Dropout(0.3)(x)
    x = L.Dense(21, use_bias=False)(x)

    model = Model(inputs=model_backbone.input, outputs=x)

    if exp_config.reg:
        for layer in model.layers:
            layer.kernel_regularizer = exp_config.reg()
            layer.bias_regularizer = exp_config.reg()
            layer.gamma_regularizer = exp_config.reg()
            layer.beta_regularizer = exp_config.reg()

    model.compile(
        loss=tf.keras.losses.CategoricalCrossentropy(
            from_logits=True,
            label_smoothing=exp_config.label_smoothing
        ), 
        optimizer="adam", metrics=["accuracy"]
    )
    
    conf_matrix_callback = ConfMatrixCallback(path_to_exp, model, Xtest, Ytest)
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        path_to_exp + '/checkpoints/{epoch:02d}',
        monitor='accuracy',
        verbose=0,
        save_best_only=False,
        save_weights_only=False,
        mode='auto',
        save_freq='epoch',
        options=None,
        initial_value_threshold=None,
    )
    print(f'Xtest={Xtest.shape}, Ytest={Ytest_onehot.shape}')
    history = model.fit(
        train_dataset, 
        batch_size=BATCH_SIZE, epochs=EPOCHS, 
        validation_data=(Xtest, Ytest_onehot), 
        callbacks=[checkpoint_callback, conf_matrix_callback],
        steps_per_epoch=ITERATIONS_PER_EPOCH
    )
    # Accuracy plot
    fig = plt.figure(figsize=(6,6))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.legend(['accuracy', 'val_accuracy'])
    fig.savefig(os.path.join(path_to_exp, 'accuracy.png'))
    plt.close(fig)
    # Loss plot
    fig = plt.figure(figsize=(6,6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.legend(['loss', 'val_loss'])
    fig.savefig(os.path.join(path_to_exp, 'loss.png'))
    plt.close(fig)
    # Save loss info
    np.save(
        f'{path_to_exp}/loss.npy', 
        np.asarray(history.history['loss'], dtype=np.float32)
    )
    np.save(
        f'{path_to_exp}/val_loss.npy', 
        np.asarray(history.history['val_loss'], dtype=np.float32)
    )
    # Save accuracy info
    np.save(
        f'{path_to_exp}/accuracy.npy', 
        np.asarray(history.history['accuracy'], dtype=np.float32)
    )
    np.save(
        f'{path_to_exp}/val_accuracy.npy', 
        np.asarray(history.history['val_accuracy'], dtype=np.float32)
    )

# %%
def create_kfolds(path_to_exp_folder: str):
    # First - collect all data into massive
    data_path = []
    labels = []
    for single_folder in glob(os.path.join(PATH_DATASET, '*')):
        # Each folder - collect images
        folder_class = single_folder.split('/')[-1]
        for single_img_path in glob(os.path.join(single_folder, '*')):
            single_img_path = '/'.join(single_img_path.split('/')[-2:])
            data_path.append(single_img_path)
            labels.append(foldername2class[folder_class])
    # Second - shuffle dataset and create kfold obj
    data_path, labels = shuffle(data_path, labels)
    kf = MakiKFoldBalance(n_groups=NUM_K, shuffle_data=True)
    # Third - save each part as config file
    # i.e as json file with train and test data

    for inum_kfold, (train, test) in enumerate(kf.split(data_path, labels, NUM_CLASSES)):
        # Create folder with certain dataset config
        folder_exp_single = os.path.join(path_to_exp_folder, f'{inum_kfold}_exp')
        os.makedirs(folder_exp_single, exist_ok=True)
        config_data = {
            TRAIN: (np.asarray(copy.deepcopy(data_path))[train]).tolist(),
            TEST: (np.asarray(copy.deepcopy(data_path))[test]).tolist()
        }

        with open(os.path.join(folder_exp_single, 'config_data.json'), 'w') as fp:
            json.dump(config_data, fp)

# %%
EXP_NUMBER = 0

def model_exp(exp_config: ExpConfig):
    global EXP_NUMBER
    ResNetModel, preprocess_input = Classifiers.get(MODEL)
    exp_folder = f'{SAVE_EXP_PATH}/exp_{int(np.random.randint(0, 10_000_000))}'
    os.makedirs(exp_folder, exist_ok=True)
    with open(f'{exp_folder}/config_data.json', 'w') as fp:
        json.dump(exp_config.to_dict(), fp)
    
    create_kfolds(exp_folder)
    exp_folder_list = glob(os.path.join(exp_folder, '*_exp'))
    assert len(exp_folder) != 0
    for single_exp_folder in exp_folder_list:
        single_folder_exp(exp_config, single_exp_folder, ResNetModel, epochs=EPOCHS, batch_size=BATCH_SIZE)
        tf.keras.backend.clear_session()
    EXP_NUMBER += 1

# %%
for reg in ALL_REG:
    for label_smoothing in LABEL_SMOOTHING_VARS: 
        try:
            exp_config = ExpConfig()
            if reg is not None:
                exp_config.reg = reg
            exp_config.label_smoothing = label_smoothing
            model_exp(exp_config)
        except Exception as e:
            with open(f'log_{EXP_NUMBER}.txt', 'a') as f:
                f.write(str(e))
                f.write(traceback.format_exc())
# Out:
#   3%|▎         | 27/945 [00:00<00:03, 266.29it/s]
# Read data from config file:  config_data
# Number of elements total: 21
# 100%|██████████| 945/945 [00:03<00:00, 261.73it/s]
# 100%|██████████| 105/105 [00:00<00:00, 266.18it/s]
# train :  945
# test:  105
# Xtest=(105, 128, 128, 3), Ytest=(105, 21)
# Epoch 1/30
# 937/937 [==============================] - ETA: 0s - loss: 1.7472 - accuracy: 0.3144INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/01/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/0
# 937/937 [==============================] - 155s 150ms/step - loss: 1.7472 - accuracy: 0.3144 - val_loss: 1.8948 - val_accuracy: 0.3905
# Epoch 2/30
# 937/937 [==============================] - ETA: 0s - loss: 1.0350 - accuracy: 0.5468INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/02/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/1
# 937/937 [==============================] - 135s 144ms/step - loss: 1.0350 - accuracy: 0.5468 - val_loss: 1.9123 - val_accuracy: 0.3238
# Epoch 3/30
# 937/937 [==============================] - ETA: 0s - loss: 0.7167 - accuracy: 0.6928INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/03/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/2
# 937/937 [==============================] - 137s 146ms/step - loss: 0.7167 - accuracy: 0.6928 - val_loss: 2.5418 - val_accuracy: 0.3714
# Epoch 4/30
# 937/937 [==============================] - ETA: 0s - loss: 0.5397 - accuracy: 0.7724INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/04/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/3
# 937/937 [==============================] - 136s 145ms/step - loss: 0.5397 - accuracy: 0.7724 - val_loss: 1.7910 - val_accuracy: 0.2857
# Epoch 5/30
# 937/937 [==============================] - ETA: 0s - loss: 0.4283 - accuracy: 0.8183INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/05/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/4
# 937/937 [==============================] - 134s 143ms/step - loss: 0.4283 - accuracy: 0.8183 - val_loss: 1.4343 - val_accuracy: 0.5333
# Epoch 6/30
# 937/937 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8520INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/06/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/5
# 937/937 [==============================] - 137s 146ms/step - loss: 0.3573 - accuracy: 0.8520 - val_loss: 2.8455 - val_accuracy: 0.3143
# Epoch 7/30
# 937/937 [==============================] - ETA: 0s - loss: 0.3036 - accuracy: 0.8740INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints
assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/20
# 937/937 [==============================] - 138s 147ms/step - loss: 0.1057 - accuracy: 0.9578 - val_loss: 0.6408 - val_accuracy: 0.8190
# Epoch 22/30
# 937/937 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9561INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/22/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/21
# 937/937 [==============================] - 137s 146ms/step - loss: 0.1072 - accuracy: 0.9561 - val_loss: 0.4393 - val_accuracy: 0.8381
# Epoch 23/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0954 - accuracy: 0.9619INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/23/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/22
# 937/937 [==============================] - 138s 147ms/step - loss: 0.0954 - accuracy: 0.9619 - val_loss: 0.5748 - val_accuracy: 0.8095
# Epoch 24/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9605INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/24/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/23
# 937/937 [==============================] - 135s 144ms/step - loss: 0.0988 - accuracy: 0.9605 - val_loss: 0.8690 - val_accuracy: 0.7524
# Epoch 25/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9640INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/25/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/24
# 937/937 [==============================] - 137s 147ms/step - loss: 0.0839 - accuracy: 0.9640 - val_loss: 0.9481 - val_accuracy: 0.8476
# Epoch 26/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.9631INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/26/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/25
# 937/937 [==============================] - 134s 144ms/step - loss: 0.0913 - accuracy: 0.9631 - val_loss: 1.2061 - val_accuracy: 0.6190
# Epoch 27/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9635INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/27/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/26
# 937/937 [==============================] - 139s 148ms/step - loss: 0.0862 - accuracy: 0.9635 - val_loss: 0.8073 - val_accuracy: 0.8095
# Epoch 28/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9669INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/28/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/27
# 937/937 [==============================] - 135s 145ms/step - loss: 0.0803 - accuracy: 0.9669 - val_loss: 1.5573 - val_accuracy: 0.7143
# Epoch 29/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9671INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/29/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/28
# 937/937 [==============================] - 136s 145ms/step - loss: 0.0829 - accuracy: 0.9671 - val_loss: 1.3125 - val_accuracy: 0.6095
# Epoch 30/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9678INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/checkpoints/30/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/6_exp/conf_matrix/29
# 937/937 [==============================] - 137s 146ms/step - loss: 0.0764 - accuracy: 0.9678 - val_loss: 1.3263 - val_accuracy: 0.6667
#   2%|▏         | 22/945 [00:00<00:04, 218.74it/s]
# Read data from config file:  config_data
# Number of elements total: 21
# 100%|██████████| 945/945 [00:03<00:00, 260.86it/s]
# 100%|██████████| 105/105 [00:00<00:00, 265.61it/s]
# train :  945
# test:  105
# Xtest=(105, 128, 128, 3), Ytest=(105, 21)
# Epoch 1/30
# 937/937 [==============================] - ETA: 0s - loss: 1.8311 - accuracy: 0.2953INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/01/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/0
# 937/937 [==============================] - 152s 151ms/step - loss: 1.8311 - accuracy: 0.2953 - val_loss: 1.9385 - val_accuracy: 0.3333
# Epoch 2/30
# 937/937 [==============================] - ETA: 0s - loss: 1.0654 - accuracy: 0.5359INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/02/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/1
# 937/937 [==============================] - 139s 149ms/step - loss: 1.0654 - accuracy: 0.5359 - val_loss: 1.5751 - val_accuracy: 0.5333
# Epoch 3/30
# 937/937 [==============================] - ETA: 0s - loss: 0.7454 - accuracy: 0.6784INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/03/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/2
# 937/937 [==============================] - 138s 147ms/step - loss: 0.7454 - accuracy: 0.6784 - val_loss: 2.8697 - val_accuracy: 0.5048
# Epoch 4/30
# 937/937 [==============================] - ETA: 0s - loss: 0.5574 - accuracy: 0.7637INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/04/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix
assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/17
# 937/937 [==============================] - 139s 148ms/step - loss: 0.1209 - accuracy: 0.9507 - val_loss: 0.9159 - val_accuracy: 0.7810
# Epoch 19/30
# 937/937 [==============================] - ETA: 0s - loss: 0.1189 - accuracy: 0.9523INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/19/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/18
# 937/937 [==============================] - 137s 147ms/step - loss: 0.1189 - accuracy: 0.9523 - val_loss: 1.3118 - val_accuracy: 0.8095
# Epoch 20/30
# 937/937 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9574INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/20/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/19
# 937/937 [==============================] - 138s 147ms/step - loss: 0.1038 - accuracy: 0.9574 - val_loss: 1.1705 - val_accuracy: 0.8095
# Epoch 21/30
# 937/937 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9521INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/21/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/20
# 937/937 [==============================] - 139s 148ms/step - loss: 0.1171 - accuracy: 0.9521 - val_loss: 2.2957 - val_accuracy: 0.5524
# Epoch 22/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9602INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/22/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/21
# 937/937 [==============================] - 140s 149ms/step - loss: 0.0984 - accuracy: 0.9602 - val_loss: 0.7407 - val_accuracy: 0.8095
# Epoch 23/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9628INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/23/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/22
# 937/937 [==============================] - 138s 147ms/step - loss: 0.0929 - accuracy: 0.9628 - val_loss: 1.3803 - val_accuracy: 0.8476
# Epoch 24/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9601INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/24/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/23
# 937/937 [==============================] - 138s 147ms/step - loss: 0.0975 - accuracy: 0.9601 - val_loss: 0.5978 - val_accuracy: 0.8857
# Epoch 25/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0864 - accuracy: 0.9663INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/25/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/24
# 937/937 [==============================] - 139s 148ms/step - loss: 0.0864 - accuracy: 0.9663 - val_loss: 1.6689 - val_accuracy: 0.7714
# Epoch 26/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9648INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/26/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/25
# 937/937 [==============================] - 136s 146ms/step - loss: 0.0859 - accuracy: 0.9648 - val_loss: 0.5544 - val_accuracy: 0.8857
# Epoch 27/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9681INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/27/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/26
# 937/937 [==============================] - 139s 149ms/step - loss: 0.0775 - accuracy: 0.9681 - val_loss: 1.0368 - val_accuracy: 0.9048
# Epoch 28/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9670INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/28/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/27
# 937/937 [==============================] - 138s 147ms/step - loss: 0.0784 - accuracy: 0.9670 - val_loss: 0.5874 - val_accuracy: 0.8286
# Epoch 29/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9673INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/29/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/28
# 937/937 [==============================] - 139s 148ms/step - loss: 0.0825 - accuracy: 0.9673 - val_loss: 1.0092 - val_accuracy: 0.7905
# Epoch 30/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9715INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/checkpoints/30/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/4_exp/conf_matrix/29
# 937/937 [==============================] - 138s 148ms/step - loss: 0.0701 - accuracy: 0.9715 - val_loss: 1.1678 - val_accuracy: 0.7714
#   3%|▎         | 27/945 [00:00<00:03, 268.80it/s]
# Read data from config file:  config_data
# Number of elements total: 21
# 100%|██████████| 945/945 [00:03<00:00, 266.68it/s]
# 100%|██████████| 105/105 [00:00<00:00, 266.74it/s]
# train :  945
# test:  105
# Xtest=(105, 128, 128, 3), Ytest=(105, 21)
# Epoch 1/30
# 937/937 [==============================] - ETA: 0s - loss: 1.7968 - accuracy: 0.3015INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/1_exp/checkpoints/01/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/1_exp/conf_matrix/0
# 937/937 [==============================] - 155s 152ms/step - loss: 1.7968 - accuracy: 0.3015 - val_loss: 1.2994 - val_accuracy: 0.4286
# Epoch 2/30
# 937/937 [==============================] - ETA: 0s - loss: 0.9989 - accuracy: 0.5649INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/1_exp/checkpoints
assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/1_exp/conf_matrix/29
# 937/937 [==============================] - 142s 151ms/step - loss: 0.0777 - accuracy: 0.9695 - val_loss: 0.2066 - val_accuracy: 0.8762
#   3%|▎         | 27/945 [00:00<00:03, 269.22it/s]
# Read data from config file:  config_data
# Number of elements total: 21
# 100%|██████████| 945/945 [00:03<00:00, 265.97it/s]
# 100%|██████████| 105/105 [00:00<00:00, 268.31it/s]
# train :  945
# test:  105
# Xtest=(105, 128, 128, 3), Ytest=(105, 21)
# Epoch 1/30
# 937/937 [==============================] - ETA: 0s - loss: 1.7611 - accuracy: 0.3133INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/01/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/0
# 937/937 [==============================] - 156s 154ms/step - loss: 1.7611 - accuracy: 0.3133 - val_loss: 1.2296 - val_accuracy: 0.4762
# Epoch 2/30
# 937/937 [==============================] - ETA: 0s - loss: 0.9673 - accuracy: 0.5812INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/02/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/1
# 937/937 [==============================] - 140s 149ms/step - loss: 0.9673 - accuracy: 0.5812 - val_loss: 1.4009 - val_accuracy: 0.4381
# Epoch 3/30
# 937/937 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.7049INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/03/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/2
# 937/937 [==============================] - 140s 149ms/step - loss: 0.6892 - accuracy: 0.7049 - val_loss: 0.8794 - val_accuracy: 0.6000
# Epoch 4/30
# 937/937 [==============================] - ETA: 0s - loss: 0.5089 - accuracy: 0.7846INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/04/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/3
# 937/937 [==============================] - 139s 148ms/step - loss: 0.5089 - accuracy: 0.7846 - val_loss: 1.7405 - val_accuracy: 0.3429
# Epoch 5/30
# 937/937 [==============================] - ETA: 0s - loss: 0.4178 - accuracy: 0.8261INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/05/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/4
# 937/937 [==============================] - 139s 148ms/step - loss: 0.4178 - accuracy: 0.8261 - val_loss: 1.0233 - val_accuracy: 0.6190
# Epoch 6/30
# 937/937 [==============================] - ETA: 0s - loss: 0.3345 - accuracy: 0.8597INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/06/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/5
# 937/937 [==============================] - 139s 148ms/step - loss: 0.3345 - accuracy: 0.8597 - val_loss: 0.6155 - val_accuracy: 0.7143
# Epoch 7/30
# 937/937 [==============================] - ETA: 0s - loss: 0.2992 - accuracy: 0.8757INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/07/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/6
# 937/937 [==============================] - 140s 149ms/step - loss: 0.2992 - accuracy: 0.8757 - val_loss: 1.8578 - val_accuracy: 0.4000
# Epoch 8/30
# 937/937 [==============================] - ETA: 0s - loss: 0.2407 - accuracy: 0.8984INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/08/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/7
# 937/937 [==============================] - 139s 149ms/step - loss: 0.2407 - accuracy: 0.8984 - val_loss: 1.1666 - val_accuracy: 0.5524
# Epoch 9/30
# 937/937 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.9022INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/09/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/8
# 937/937 [==============================] - 140s 150ms/step - loss: 0.2390 - accuracy: 0.9022 - val_loss: 0.8485 - val_accuracy: 0.8190
# Epoch 10/30
# 937/937 [==============================] - ETA: 0s - loss: 0.2044 - accuracy: 0.9145INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/10/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/9
# 937/937 [==============================] - 140s 150ms/step - loss: 0.2044 - accuracy: 0.9145 - val_loss: 1.5840 - val_accuracy: 0.7810
# Epoch 11/30
# 937/937 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9243INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/11/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/10
# 937/937 [==============================] - 140s 149ms/step - loss: 0.1889 - accuracy: 0.9243 - val_loss: 1.1832 - val_accuracy: 0.7238
# Epoch 12/30
# 937/937 [==============================] - ETA: 0s - loss: 0.1721 - accuracy: 0.9281INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/12/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix
assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/27
# 937/937 [==============================] - 140s 150ms/step - loss: 0.0822 - accuracy: 0.9661 - val_loss: 1.2672 - val_accuracy: 0.7905
# Epoch 29/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9651INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/29/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/28
# 937/937 [==============================] - 140s 150ms/step - loss: 0.0816 - accuracy: 0.9651 - val_loss: 0.5958 - val_accuracy: 0.8571
# Epoch 30/30
# 937/937 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9674INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/checkpoints/30/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/3_exp/conf_matrix/29
# 937/937 [==============================] - 141s 150ms/step - loss: 0.0768 - accuracy: 0.9674 - val_loss: 0.8552 - val_accuracy: 0.7143
#   2%|▏         | 22/945 [00:00<00:04, 214.87it/s]
# Read data from config file:  config_data
# Number of elements total: 21
# 100%|██████████| 945/945 [00:03<00:00, 260.70it/s]
# 100%|██████████| 105/105 [00:00<00:00, 266.76it/s]
# train :  945
# test:  105
# Xtest=(105, 128, 128, 3), Ytest=(105, 21)
# Epoch 1/30
# 937/937 [==============================] - ETA: 0s - loss: 1.8992 - accuracy: 0.2750INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/01/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/0
# 937/937 [==============================] - 157s 154ms/step - loss: 1.8992 - accuracy: 0.2750 - val_loss: 1.7116 - val_accuracy: 0.3429
# Epoch 2/30
# 937/937 [==============================] - ETA: 0s - loss: 1.1242 - accuracy: 0.5092INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/02/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/1
# 937/937 [==============================] - 142s 151ms/step - loss: 1.1242 - accuracy: 0.5092 - val_loss: 0.9933 - val_accuracy: 0.5429
# Epoch 3/30
# 937/937 [==============================] - ETA: 0s - loss: 0.8076 - accuracy: 0.6533INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/03/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/2
# 937/937 [==============================] - 142s 151ms/step - loss: 0.8076 - accuracy: 0.6533 - val_loss: 0.8036 - val_accuracy: 0.6381
# Epoch 4/30
# 937/937 [==============================] - ETA: 0s - loss: 0.6033 - accuracy: 0.7476INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/04/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/3
# 937/937 [==============================] - 137s 146ms/step - loss: 0.6033 - accuracy: 0.7476 - val_loss: 1.8804 - val_accuracy: 0.3810
# Epoch 5/30
# 937/937 [==============================] - ETA: 0s - loss: 0.4585 - accuracy: 0.8115INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/05/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/4
# 937/937 [==============================] - 142s 152ms/step - loss: 0.4585 - accuracy: 0.8115 - val_loss: 0.8818 - val_accuracy: 0.6762
# Epoch 6/30
# 937/937 [==============================] - ETA: 0s - loss: 0.3625 - accuracy: 0.8506INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/06/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/5
# 937/937 [==============================] - 141s 150ms/step - loss: 0.3625 - accuracy: 0.8506 - val_loss: 0.5087 - val_accuracy: 0.7905
# Epoch 7/30
# 937/937 [==============================] - ETA: 0s - loss: 0.3024 - accuracy: 0.8748INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/07/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/6
# 937/937 [==============================] - 139s 149ms/step - loss: 0.3024 - accuracy: 0.8748 - val_loss: 2.2333 - val_accuracy: 0.6381
# Epoch 8/30
# 937/937 [==============================] - ETA: 0s - loss: 0.2475 - accuracy: 0.8975INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/08/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/7
# 937/937 [==============================] - 141s 150ms/step - loss: 0.2475 - accuracy: 0.8975 - val_loss: 0.6191 - val_accuracy: 0.7905
# Epoch 9/30
# 937/937 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.9047INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/09/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/8
# 937/937 [==============================] - 140s 150ms/step - loss: 0.2338 - accuracy: 0.9047 - val_loss: 0.4195 - val_accuracy: 0.8381
# Epoch 10/30
# 937/937 [==============================] - ETA: 0s - loss: 0.2040 - accuracy: 0.9156INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/10/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/9
# 937/937 [==============================] - 139s 149ms/step - loss: 0.2040 - accuracy: 0.9156 - val_loss: 0.6319 - val_accuracy: 0.7619
# Epoch 11/30
# 937/937 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9220INFO:tensorflow:Assets written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/checkpoints/11/assets
# INFO:tensorflow:Confusion matrix written to: /raid/rustam/danil/beams_loss_test/exp_5039095/5_exp/conf_matrix/10
# 937/937 [==============================] - 138s 147ms/step - loss: 0.1897 - accuracy: 0.9220 - val_loss: 0.9130 - val_accuracy: 0.7714
# Epoch 12/30
# 489/937 [==============>...............] - ETA: 45s - loss: 0.1929 - accuracy: 0.9218

# %%
ResNetModel, preprocess_input = Classifiers.get(MODEL)

# %%
model_backbone = ResNetModel(
    include_top=False, weights=None, 
    input_shape=(128, 128, 3)
)

# %%
layer = model_backbone.get_layer('relu0')
layer.kernel_regularizer = tf.keras.regularizers.l2(1e-4)
layer.bias_regularizer = tf.keras.regularizers.l2(1e-4)
layer.gamma_regularizer = tf.keras.regularizers.l2(1e-4)
layer.beta_regularizer = tf.keras.regularizers.l2(1e-4)

# %%
layer.get_config()

# %%
for layer in model_backbone.layers:
    layer.kernel_regularizer = tf.keras.regularizers.l2(1e-4)
    layer.bias_regularizer = tf.keras.regularizers.l2(1e-4)
    layer.gamma_regularizer = tf.keras.regularizers.l2(1e-4)
    layer.beta_regularizer = tf.keras.regularizers.l2(1e-4)

# %%
model_backbone.summary()

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import tensorflow_addons as tfa

Xtrain = []
Ytrain = []

for _ in range(100):
    xxx = np.random.randn(128, 128, 3).astype(np.int64) * 0.0
    xxx[32:80, 32:80] = 255
    Xtrain.append(xxx)
    Ytrain.append(int(np.random.randint(0, 21)))
Xtrain = np.asarray(Xtrain).astype(np.float32)
Ytrain_onehot = to_categorical(np.asarray(Ytrain).astype(np.int32)).astype(np.float32)
batch_size=32

# %%
ddd = next(iter(tf_dataset))

# %%
plt.imshow(ddd[0][0])

# %%
Xtrain, Ytrain, Xtest, Ytest, pred2params, config_data = load_data(
    path_exp_folder='/mnt/data/danil/beams_loss_test/exp_0/0_exp',
    path_to_data=PATH_DATASET,
    use_saved=True,
    size_hw=(128, 128),
    test_percent=None,
    data_type=CLASSIFICATION,
    filename_config='config_data'
)

# %%
Ytrain_onehot = to_categorical(Ytrain)

# %%
Ytest_onehot = to_categorical(Ytest)
Ytest_onehot.shape

# %%
train_dataset = create_dataset(Xtrain, Ytrain_onehot, BATCH_SIZE)

# %%
ddd = next(iter(train_dataset))

# %%
Xtest, _ = normalize_data(np.asarray(Xtest), None)

# %%
Xtest.shape

# %%
plt.imshow((ddd[0][0] + 1)/2.0)
